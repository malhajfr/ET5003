# %% [markdown]
# <div>
# <img src="https://drive.google.com/uc?export=view&id=1vK33e_EqaHgBHcbRV_m38hx6IkG0blK_" width="350"/>
# </div>
#
#
# ## ET5003_CS6134  Machine Learning Applications
# ## SEM1 2022/3
#
# ### ET5003_CS6134 Etivity 1 - Data Preprocessing and Training a Machine Learning Model
#
# ### Instructor: Emil Vassev
# Sept 13th, 2022
# <br><br>
# Copyright (C) 2022 - All rights reserved, do not copy or distribute without permission of the author.
# ***

# %% [markdown]
# ## Submission Info
# ### Student Name: <span style="color:red">Mahmoud</span>
# ### Student Surname: <span style="color:red">Alhaj</span>
# ### Student ID: <span style="color:red">22273468</span>
# ### Date of Final Submission: <span style="color:red">06 11 2023</span>
# ***

# %% [markdown]
# ## Introduction
# Real-world datasets for ML are expected to be *incomplete*, *inconsistent*, and *noisy* due to their heterogeneous origin. Applying ML algorithms on such data would not give quality results as they would fail to identify patterns effectively.
#
# **Data Preprocessing** is a part of the ML process, which strives to improve the overall data quality by dealing with:
# * duplicate or missing values - such data may give an incorrect view of the overall statistics of data;
# * outliers and inconsistent data points - such data often tend to disturb the model’s overall learning and thus, leading to false predictions.
#
# Data Preprocessing targets ML features, which are:
# * individual independent variables operating as inputs to ML models;
# * representations or attributes that describe the data and help the models to predict the classes/labels.
#
# Example: features in a structured dataset (e.g., in a CSV format) refer to each column representing a measurable piece of data that can be used for analysis: name, age, sex, fare, etc.
#
# **Model Training** is a primary step in ML in which a ML algorithm is fed with sufficient training data to learn from. Model Training results in a working ML model that can then be validated, tested and deployed.
#
# ## Task
# In this e-tivity, you are asked to follow the ML process to:
# * preprocess a provided dataset, so it will become suitable for ML operations;
# * select an appropriate ML model, so it will cope with the specifics of data and ML tasks;
# * train the selected ML model on the preprocessed dataset;
# * test the selected ML model on the preprocessed dataset.
#
# Please, consult the lectures of Weeks #1 and #2 for the specifics of the different ML models, the Data Preprocessing staeps and the specifics of Model Training and Testing.
#
# ## The Dataset
# The provided dataset covers bond trading operations (buy and sell) on a financial market. The data is labeled and provided in its raw format, so it needs to be preprocessed.

# %% [markdown]
# The provided dataset can be loaded as following:

# %%
import pandas as pd

url_dataset = "https://raw.githubusercontent.com/evassev/ET5003_SEM1_2022/main/Etivities/data/trade_combined.csv"
df = pd.read_csv(url_dataset)

df.head(10)
# Out:
#    NoRelatedSym     Symbol SymbolSfx  SecurityID  SecurityIDSource  \
# 0             1  135087L93        WI         NaN                 1
# 1             1  135087L93        WI         NaN                 1
# 2             1  135087L93        WI         NaN                 1
# 3             1  135087L93        WI         NaN                 1
# 4             1  135087L93        WI         NaN                 1
# 5             1  135087M76        WI         NaN                 1
# 6             1  135087M76        WI         NaN                 1
# 7             1  135087M76        WI         NaN                 1
# 8             1  135087M76        WI         NaN                 1
# 9             1  135087L93        WI         NaN                 1
#
#   SecurityType MaturityDate       IssueDate  Side  OrderQty  ... NoPartIDs  \
# 0         BOND     9/1/2026  4/16/2021 0:00   BUY   2400000  ...         1
# 1         BOND     9/1/2026  4/16/2021 0:00   BUY   2400000  ...         1
# 2         BOND     9/1/2026  4/16/2021 0:00   BUY   2400000  ...         1
# 3         BOND     9/1/2026  4/16/2021 0:00   BUY   2400000  ...         1
# 4         BOND     9/1/2026  4/16/2021 0:00   BUY   2400000  ...         1
# 5         BOND    11/1/2023   8/9/2021 0:00  SELL  15000000  ...         1
# 6         BOND    11/1/2023   8/9/2021 0:00  SELL  15000000  ...         1
# 7         BOND    11/1/2023   8/9/2021 0:00  SELL  15000000  ...         1
# 8         BOND    11/1/2023   8/9/2021 0:00  SELL  15000000  ...         1
# 9         BOND     9/1/2026  4/16/2021 0:00  SELL    600000  ...         1
#
#   PartyID  DealerID DealerTraderID  CustomerTraderID  CustomerID  \
# 0       1       334        10792.0              6549         129
# 1       1       335       117793.0              6549         129
# 2       1       325       119290.0              6549         129
# 3       1       327       113852.0              6549         129
# 4       1       337       117795.0              6549         129
# 5       1       325       119752.0              7019         277
# 6       1       336       117794.0              7019         277
# 7       1       323       117786.0              7019         277
# 8       1       337       117795.0              7019         277
# 9       1       335       117793.0             11532         177
#
#    PartyIDSource  PartyRole  DealerCount  OrdSubType
# 0              D         13            5    OUTRIGHT
# 1              D         13            5    OUTRIGHT
# 2              D         13            5    OUTRIGHT
# 3              D         13            5    OUTRIGHT
# 4              D         13            5    OUTRIGHT
# 5              D         13            4    OUTRIGHT
# 6              D         13            4    OUTRIGHT
# 7              D         13            4    OUTRIGHT
# 8              D         13            4    OUTRIGHT
# 9              D         13            4    OUTRIGHT
#
# [10 rows x 27 columns]

# %% [markdown]
# ## Target: In this task you are asked to predict the  <span style="color:red">Bond Price</span>.

# %% [markdown]
# ## Note: In the following steps use the dataframe object <span style="color:red">df</span>.

# %% [markdown]
# ## Here are the steps you need to follow:

# %% [markdown]
# # Step 1: Determine the ML Model: Supervised-Classification, Supervised-Regression, or Unsupervised ML Model.  (10%)
#
# Supervised-Regression is best fit for this kind of problem.Using supervised regression for predicting bond prices allows you to utilize past data to make informed predictions about future prices. Supervised regression is used when the outcome variable is continuous. Since bond prices are continuous variables, regression can model the relationship between bond prices and predictors accurately.

# %% [markdown]
# <span style="color:red"></span>

# %% [markdown]
# # Step 2: Data Preprocessing.  (70%)

# %% [markdown]
# ## Step 2.1: Specifics of the dataset.  (10%)
# <span style="color:red">
#     TODO: Show the specifics of the dataset in terms of:
#     <ul>
#     <li>shape</li>
#     <li>columns (features)</li>
#     <li>data types</li>
#     <li>statistics for the 'Price' feature</li>
#     <li>plot the 'Price' feature</li>
#     </ul>
# </span>

# %%
df.shape
# Out:
# (20000, 27)

# %%
df.describe()
# Out:
#        NoRelatedSym    SecurityID  SecurityIDSource      OrderQty  OrdType  \
# count       20000.0  6.041000e+03           20000.0  2.000000e+04  20000.0
# mean            1.0  1.085207e+06               1.0  4.622230e+06      1.0
# std             0.0  6.235101e+05               0.0  1.210594e+07      0.0
# min             1.0  1.466490e+05               1.0  1.000000e+03      1.0
# 25%             1.0  5.971960e+05               1.0  1.000000e+05      1.0
# 50%             1.0  1.076888e+06               1.0  8.020000e+05      1.0
# 75%             1.0  1.657785e+06               1.0  4.000000e+06      1.0
# max             1.0  2.314916e+06               1.0  2.500000e+08      1.0
#
#               Price  PriceType         Yield  NoPartIDs  PartyID  \
# count  18692.000000    20000.0  18703.000000    20000.0  20000.0
# mean     107.535666        1.0      1.653129        1.0      1.0
# std       14.445474        0.0      0.867016        0.0      0.0
# min        0.000000        1.0     -0.032000        1.0      1.0
# 25%       99.749750        1.0      0.996000        1.0      1.0
# 50%      103.324500        1.0      1.707000        1.0      1.0
# 75%      110.360500        1.0      2.241000        1.0      1.0
# max      174.278000        1.0     26.131000        1.0      1.0
#
#            DealerID  DealerTraderID  CustomerTraderID    CustomerID  \
# count  20000.000000    18945.000000      20000.000000  20000.000000
# mean     331.217900    73717.118131      56223.862150    215.349650
# std        7.684697    52817.470148      54029.108707    296.486613
# min      321.000000     5156.000000       5487.000000      2.000000
# 25%      325.000000    10796.000000       6549.000000     57.000000
# 50%      334.000000   114410.000000      12806.000000    129.000000
# 75%      336.000000   117794.000000     116307.000000    248.000000
# max      448.000000   119844.000000     120031.000000   3436.000000
#
#        PartyRole   DealerCount
# count    20000.0  20000.000000
# mean        13.0      3.750300
# std          0.0      0.773809
# min         13.0      1.000000
# 25%         13.0      4.000000
# 50%         13.0      4.000000
# 75%         13.0      4.000000
# max         13.0      5.000000

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 20000 entries, 0 to 19999
# Data columns (total 27 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   NoRelatedSym      20000 non-null  int64
#  1   Symbol            20000 non-null  object
#  2   SymbolSfx         20000 non-null  object
#  3   SecurityID        6041 non-null   float64
#  4   SecurityIDSource  20000 non-null  int64
#  5   SecurityType      20000 non-null  object
#  6   MaturityDate      20000 non-null  object
#  7   IssueDate         20000 non-null  object
#  8   Side              20000 non-null  object
#  9   OrderQty          20000 non-null  int64
#  10  SettlDate         20000 non-null  object
#  11  Currency          20000 non-null  object
#  12  OrdType           20000 non-null  int64
#  13  TransactTime      20000 non-null  object
#  14  Price             18692 non-null  float64
#  15  PriceType         20000 non-null  int64
#  16  Yield             18703 non-null  float64
#  17  NoPartIDs         20000 non-null  int64
#  18  PartyID           20000 non-null  int64
#  19  DealerID          20000 non-null  int64
#  20  DealerTraderID    18945 non-null  float64
#  21  CustomerTraderID  20000 non-null  int64
#  22  CustomerID        20000 non-null  int64
#  23  PartyIDSource     20000 non-null  object
#  24  PartyRole         20000 non-null  int64
#  25  DealerCount       20000 non-null  int64
#  26  OrdSubType        20000 non-null  object
# dtypes: float64(4), int64(12), object(11)
# memory usage: 4.1+ MB

# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# Sample DataFrame creation
# Let's assume your DataFrame is named 'df' and the price column is named 'price'

# df = pd.read_csv('your_data.csv')  # Assuming the data is in a CSV file
# df = pd.DataFrame(data)  # Assuming you have the data in some other format

# Display basic statistics
print(df['Price'].describe())

# Histogram of the 'price' column to show distribution
sns.histplot(data = df['Price'], kde=True, bins = 50,stat="density", fill=False)
# sns.kdeplot(data = df['Price'], color="g")
plt.title('Price Distribution')
plt.xlabel('Price')
plt.ylabel('Frequency')
plt.show()

# Boxplot of the 'price' column to show spread and outliers
sns.boxplot(x=df['Price'],)
plt.title('Price Spread')
plt.xlabel('Price')
plt.show()

# You can also combine both the histogram and the boxplot using seaborn's `violinplot` for a more comprehensive view
sns.violinplot(x=df['Price'])
plt.title('Price Distribution and Spread')
plt.xlabel('Price')
plt.show()
# Out:
# count    18692.000000
# mean       107.535666
# std         14.445474
# min          0.000000
# 25%         99.749750
# 50%        103.324500
# 75%        110.360500
# max        174.278000
# Name: Price, dtype: float64

# %% [markdown]
# ## Step 2.2: Data Cleaning: Remove features with unique values for each row in the dataset. (10%)
# <span style="color:red">
#     TODO:
#     <ul>
#     <li>Show the features with unique values for each row in the dataset.</li>
#     <li>Remove the features with unique values for each row in the dataset.</li>
#     </ul>
# </span>

# %%
df.shape
# Out:
# (20000, 27)

# %%
df.nunique()
# Out:
# NoRelatedSym            1
# Symbol                411
# SymbolSfx               1
# SecurityID           1912
# SecurityIDSource        1
# SecurityType            4
# MaturityDate          311
# IssueDate             402
# Side                    2
# OrderQty             1249
# SettlDate              99
# Currency                1
# OrdType                 1
# TransactTime         4130
# Price               12112
# PriceType               1
# Yield                3287
# NoPartIDs               1
# PartyID                 1
# DealerID               14
# DealerTraderID        160
# CustomerTraderID      389
# CustomerID            170
# PartyIDSource           1
# PartyRole               1
# DealerCount             5
# OrdSubType              1
# dtype: int64

# %%
for column in df.columns:
  print(df[column].describe(),'\n\n')
# Out:
# count    20000.0
# mean         1.0
# std          0.0
# min          1.0
# 25%          1.0
# 50%          1.0
# 75%          1.0
# max          1.0
# Name: NoRelatedSym, dtype: float64
#
#
# count         20000
# unique          411
# top       135087H72
# freq           1007
# Name: Symbol, dtype: object
#
#
# count     20000
# unique        1
# top          WI
# freq      20000
# Name: SymbolSfx, dtype: object
#
#
# count    6.041000e+03
# mean     1.085207e+06
# std      6.235101e+05
# min      1.466490e+05
# 25%      5.971960e+05
# 50%      1.076888e+06
# 75%      1.657785e+06
# max      2.314916e+06
# Name: SecurityID, dtype: float64
#
#
# count    20000.0
# mean         1.0
# std          0.0
# min          1.0
# 25%          1.0
# 50%          1.0
# 75%          1.0
# max          1.0
# Name: SecurityIDSource, dtype: float64
#
#
# count     20000
# unique        4
# top        BOND
# freq      13959
# Name: SecurityType, dtype: object
#
#
# count         20000
# unique          311
# top       12/1/2051
# freq           1136
# Name: MaturityDate, dtype: object
#
#
# count               20000
# unique                402
# top       12/22/2017 0:00
# freq                 1007
# Name: IssueDate, dtype: object
#
#
# count     20000
# unique        2
# top        SELL
# freq      10877
# Name: Side, dtype: object
#
#
# count    2.000000e+04
# mean     4.622230e+06
# std      1.210594e+07
# min      1.000000e+03
# 25%      1.000000e+05
# 50%      8.020000e+05
# 75%      4.000000e+06
# max      2.500000e+08
# Name: OrderQty, dtype: float64
#
#
# count         20000
# unique           99
# top       2/26/2021
# freq           1709
# Name: SettlDate, dtype: object
#
#
# count     20000
# unique        1
# top         EUR
# freq      20000
# Name: Currency, dtype: object
#
#
# count    20000.0
# mean         1.0
# std          0.0
# min          1.0
# 25%          1.0
# 50%          1.0
# 75%          1.0
# max          1.0
# Name: OrdType, dtype: float64
#
#
# count        20000
# unique        4130
# top       14:46:19
# freq           120
# Name: TransactTime, dtype: object
#
#
# count    18692.000000
# mean       107.535666
# std         14.445474
# min          0.000000
# 25%         99.749750
# 50%        103.324500
# 75%        110.360500
# max        174.278000
# Name: Price, dtype: float64
#
#
# count    20000.0
# mean         1.0
# std          0.0
# min          1.0
# 25%          1.0
# 50%          1.0
# 75%          1.0
# max          1.0
# Name: PriceType, dtype: float64
#
#
# count    18703.000000
# mean         1.653129
# std          0.867016
# min         -0.032000
# 25%          0.996000
# 50%          1.707000
# 75%          2.241000
# max         26.131000
# Name: Yield, dtype: float64
#
#
# count    20000.0
# mean         1.0
# std          0.0
# min          1.0
# 25%          1.0
# 50%          1.0
# 75%          1.0
# max          1.0
# Name: NoPartIDs, dtype: float64
#
#
# count    20000.0
# mean         1.0
# std          0.0
# min          1.0
# 25%          1.0
# 50%          1.0
# 75%          1.0
# max          1.0
# Name: PartyID, dtype: float64
#
#
# count    20000.000000
# mean       331.217900
# std          7.684697
# min        321.000000
# 25%        325.000000
# 50%        334.000000
# 75%        336.000000
# max        448.000000
# Name: DealerID, dtype: float64
#
#
# count     18945.000000
# mean      73717.118131
# std       52817.470148
# min        5156.000000
# 25%       10796.000000
# 50%      114410.000000
# 75%      117794.000000
# max      119844.000000
# Name: DealerTraderID, dtype: float64
#
#
# count     20000.000000
# mean      56223.862150
# std       54029.108707
# min        5487.000000
# 25%        6549.000000
# 50%       12806.000000
# 75%      116307.000000
# max      120031.000000
# Name: CustomerTraderID, dtype: float64
#
#
# count    20000.000000
# mean       215.349650
# std        296.486613
# min          2.000000
# 25%         57.000000
# 50%        129.000000
# 75%        248.000000
# max       3436.000000
# Name: CustomerID, dtype: float64
#
#
# count     20000
# unique        1
# top           D
# freq      20000
# Name: PartyIDSource, dtype: object
#
#
# count    20000.0
# mean        13.0
# std          0.0
# min         13.0
# 25%         13.0
# 50%         13.0
# 75%         13.0
# max         13.0
# Name: PartyRole, dtype: float64
#
#
# count    20000.000000
# mean         3.750300
# std          0.773809
# min          1.000000
# 25%          4.000000
# 50%          4.000000
# 75%          4.000000
# max          5.000000
# Name: DealerCount, dtype: float64
#
#
# count        20000
# unique           1
# top       OUTRIGHT
# freq         20000
# Name: OrdSubType, dtype: object

# %%
# Assuming `df` is your pandas DataFrame
unique_value_columns_to_remove = [col for col in df.columns if df[col].nunique() == len(df)]

# Remove these columns from the DataFrame
df.drop(columns=unique_value_columns_to_remove,axis=1,inplace=True)

# %%
# df_cleaned = df.drop(columns=columns_to_remove)
# df_cleaned
len(df.columns)
# Out:
# 27

# %% [markdown]
# ## Step 2.3: Data Cleaning: Remove features with one unique value for the entire dataset. (10%)
# <span style="color:red">
#     TODO:
#     <ul>
#     <li>Show the features with one unique value for the entire dataset.</li>
#     <li>Remove the features with one unique value for the entire dataset.</li>
#     </ul>
# </span>

# %%
one_unique_value_columns_to_remove = df.columns[df.nunique() == 1]

# %%
one_unique_value_columns_to_remove
# Out:
# Index(['NoRelatedSym', 'SymbolSfx', 'SecurityIDSource', 'Currency', 'OrdType',
#        'PriceType', 'NoPartIDs', 'PartyID', 'PartyIDSource', 'PartyRole',
#        'OrdSubType'],
#       dtype='object')

# %%
len(one_unique_value_columns_to_remove)
# Out:
# 11

# %%
# Assuming `df` is your pandas DataFrame
# columns_to_drop = [col for col in df.columns if df[col].nunique() == 1]

# %%
# Drop these columns from the DataFrame
df.drop(columns=one_unique_value_columns_to_remove,axis =1, inplace=True)

# If you want to verify the result

# %%
len(df.columns)
# Out:
# 16

# %% [markdown]
# ## Step 2.4: Data Cleaning: Remove records with null (NAN) values. (10%)
# <span style="color:red">
#     TODO:
#     <ul>
#     <li>Show the number of null values per feature.</li>
#     <li>For any feature, remove the rows containg a null value.</li>
#     </ul>
# </span>

# %%
nan_counts = df.isna().sum()
print(nan_counts)
#nan_counts = df.isna().sum()/len(df)
# Out:
# Symbol                  0
# SecurityID          13959
# SecurityType            0
# MaturityDate            0
# IssueDate               0
# Side                    0
# OrderQty                0
# SettlDate               0
# TransactTime            0
# Price                1308
# Yield                1297
# DealerID                0
# DealerTraderID       1055
# CustomerTraderID        0
# CustomerID              0
# DealerCount             0
# dtype: int64

# %%
df.dropna()
# Out:
#           Symbol  SecurityID SecurityType MaturityDate       IssueDate  Side  \
# 6204   135087D35   1657312.0          GOC    12/1/2048   6/2/2014 0:00   BUY
# 6205   135087D35   1657312.0          GOC    12/1/2048   6/2/2014 0:00   BUY
# 6206   135087H80   1657313.0          GOC     5/1/2020   2/9/2018 0:00  SELL
# 6207   135087D35   1657317.0          GOC    12/1/2048   6/2/2014 0:00   BUY
# 6208   135087D35   1657317.0          GOC    12/1/2048   6/2/2014 0:00   BUY
# ...          ...         ...          ...          ...             ...   ...
# 19995  135087A38    147039.0          GOC     8/1/2015  4/26/2013 0:00  SELL
# 19996  135087A38    147038.0          GOC     8/1/2015  4/26/2013 0:00   BUY
# 19997  013051CZ8    147033.0         PROV    12/1/2019  9/28/2009 0:00  SELL
# 19998  135087A38    147039.0          GOC     8/1/2015  4/26/2013 0:00  SELL
# 19999  013051CZ8    147033.0         PROV    12/1/2019  9/28/2009 0:00  SELL
#
#        OrderQty  SettlDate TransactTime    Price  Yield  DealerID  \
# 6204    1000000  6/20/2018     14:39:50  111.140  2.243       334
# 6205    1000000  6/20/2018     14:39:50  111.220  2.240       335
# 6206    5000000  6/20/2018     14:40:12   99.760  1.881       323
# 6207    1250000  6/20/2018     14:41:05  111.198  2.241       321
# 6208    1250000  6/20/2018     14:41:05  111.130  2.244       327
# ...         ...        ...          ...      ...    ...       ...
# 19995  12000000  6/24/2013     14:51:56  100.651  1.186       334
# 19996  50000000  6/24/2013     14:51:53  100.653  1.185       334
# 19997    700000  6/25/2013     14:50:59  109.000  2.478       332
# 19998  12000000  6/24/2013     14:51:56  100.645  1.189       330
# 19999    700000  6/25/2013     14:50:59  109.099  2.462       330
#
#        DealerTraderID  CustomerTraderID  CustomerID  DealerCount
# 6204         113683.0             11570         454            4
# 6205         114347.0             11570         454            4
# 6206         118599.0              6753         204            1
# 6207           7177.0              6687         178            4
# 6208           7687.0              6687         178            4
# ...               ...               ...         ...          ...
# 19995         10792.0              7025         280            4
# 19996         10792.0              6753         204            1
# 19997         10567.0              7053         292            4
# 19998          9970.0              7025         280            4
# 19999         10189.0              7053         292            4
#
# [5685 rows x 16 columns]

# %% [markdown]
# ## Step 2.5: Data Transformation: Convert all non-numeric features to numeric. (30%)
# <span style="color:red">
#     TODO:
#     <ul>
#     <li>Show all non-numeric features.</li>
#     <li>Convert the non-numeric features to numeric.</li>
#     </ul>
# </span>

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 20000 entries, 0 to 19999
# Data columns (total 16 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   Symbol            20000 non-null  object
#  1   SecurityID        6041 non-null   float64
#  2   SecurityType      20000 non-null  object
#  3   MaturityDate      20000 non-null  object
#  4   IssueDate         20000 non-null  object
#  5   Side              20000 non-null  object
#  6   OrderQty          20000 non-null  int64
#  7   SettlDate         20000 non-null  object
#  8   TransactTime      20000 non-null  object
#  9   Price             18692 non-null  float64
#  10  Yield             18703 non-null  float64
#  11  DealerID          20000 non-null  int64
#  12  DealerTraderID    18945 non-null  float64
#  13  CustomerTraderID  20000 non-null  int64
#  14  CustomerID        20000 non-null  int64
#  15  DealerCount       20000 non-null  int64
# dtypes: float64(4), int64(5), object(7)
# memory usage: 2.4+ MB

# %%
non_numeric_features = df.select_dtypes(exclude=['number'])
non_numeric_features
# Out:
#           Symbol SecurityType MaturityDate       IssueDate  Side   SettlDate  \
# 0      135087L93         BOND     9/1/2026  4/16/2021 0:00   BUY  12/16/2021
# 1      135087L93         BOND     9/1/2026  4/16/2021 0:00   BUY  12/16/2021
# 2      135087L93         BOND     9/1/2026  4/16/2021 0:00   BUY  12/16/2021
# 3      135087L93         BOND     9/1/2026  4/16/2021 0:00   BUY  12/16/2021
# 4      135087L93         BOND     9/1/2026  4/16/2021 0:00   BUY  12/16/2021
# ...          ...          ...          ...             ...   ...         ...
# 19995  135087A38          GOC     8/1/2015  4/26/2013 0:00  SELL   6/24/2013
# 19996  135087A38          GOC     8/1/2015  4/26/2013 0:00   BUY   6/24/2013
# 19997  013051CZ8         PROV    12/1/2019  9/28/2009 0:00  SELL   6/25/2013
# 19998  135087A38          GOC     8/1/2015  4/26/2013 0:00  SELL   6/24/2013
# 19999  013051CZ8         PROV    12/1/2019  9/28/2009 0:00  SELL   6/25/2013
#
#       TransactTime
# 0         15:20:43
# 1         15:20:43
# 2         15:20:43
# 3         15:20:43
# 4         15:20:43
# ...            ...
# 19995     14:51:56
# 19996     14:51:53
# 19997     14:50:59
# 19998     14:51:56
# 19999     14:50:59
#
# [20000 rows x 7 columns]

# %%
# Define the pattern you want to search for in column names
pattern_date = 'Date'
pattern_time = 'Time'


# Find columns with names containing the specified pattern
matching_date_columns = [col for col in df.columns if pattern_date in col]


# Convert the 'Date' column to numeric values (Unix timestamps)

for col in matching_date_columns:
  # df[col] = pd.to_datetime(df[col]).astype(int)
  df[col] = pd.to_datetime(df[col]).dt.strftime('%Y%m%d').astype(int)



# Find columns with names containing the specified pattern
matching_time_columns = [col for col in df.columns if pattern_time in col]


# Convert the 'Date' column to numeric values (Unix timestamps)

for col in matching_time_columns:
  # df[col] = pd.to_datetime(df[col]).astype(int)
  df[col] = pd.to_datetime(df[col]).dt.strftime('%Y%m%d').astype(int)



# Display the DataFrame with numeric date values
df
# Out:
#           Symbol  SecurityID SecurityType  MaturityDate  IssueDate  Side  \
# 0      135087L93         NaN         BOND      20260901   20210416   BUY
# 1      135087L93         NaN         BOND      20260901   20210416   BUY
# 2      135087L93         NaN         BOND      20260901   20210416   BUY
# 3      135087L93         NaN         BOND      20260901   20210416   BUY
# 4      135087L93         NaN         BOND      20260901   20210416   BUY
# ...          ...         ...          ...           ...        ...   ...
# 19995  135087A38    147039.0          GOC      20150801   20130426  SELL
# 19996  135087A38    147038.0          GOC      20150801   20130426   BUY
# 19997  013051CZ8    147033.0         PROV      20191201   20090928  SELL
# 19998  135087A38    147039.0          GOC      20150801   20130426  SELL
# 19999  013051CZ8    147033.0         PROV      20191201   20090928  SELL
#
#        OrderQty  SettlDate  TransactTime    Price  Yield  DealerID  \
# 0       2400000   20211216      20231114      NaN    NaN       334
# 1       2400000   20211216      20231114   98.720  1.281       335
# 2       2400000   20211216      20231114   98.720  1.281       325
# 3       2400000   20211216      20231114   98.711  1.283       327
# 4       2400000   20211216      20231114   98.699  1.286       337
# ...         ...        ...           ...      ...    ...       ...
# 19995  12000000   20130624      20231114  100.651  1.186       334
# 19996  50000000   20130624      20231114  100.653  1.185       334
# 19997    700000   20130625      20231114  109.000  2.478       332
# 19998  12000000   20130624      20231114  100.645  1.189       330
# 19999    700000   20130625      20231114  109.099  2.462       330
#
#        DealerTraderID  CustomerTraderID  CustomerID  DealerCount
# 0             10792.0              6549         129            5
# 1            117793.0              6549         129            5
# 2            119290.0              6549         129            5
# 3            113852.0              6549         129            5
# 4            117795.0              6549         129            5
# ...               ...               ...         ...          ...
# 19995         10792.0              7025         280            4
# 19996         10792.0              6753         204            1
# 19997         10567.0              7053         292            4
# 19998          9970.0              7025         280            4
# 19999         10189.0              7053         292            4
#
# [20000 rows x 16 columns]

# %%
# df_encoded = pd.get_dummies(df, columns=non_numeric_features.columns)
# df_encoded

# %% [markdown]
# # Step 3: Model Training and Testing.  (20%)

# %%
df.shape
# Out:
# (20000, 16)

# %%
df.head(10)
# Out:
#       Symbol  SecurityID SecurityType  MaturityDate  IssueDate  Side  \
# 0  135087L93         NaN         BOND      20260901   20210416   BUY
# 1  135087L93         NaN         BOND      20260901   20210416   BUY
# 2  135087L93         NaN         BOND      20260901   20210416   BUY
# 3  135087L93         NaN         BOND      20260901   20210416   BUY
# 4  135087L93         NaN         BOND      20260901   20210416   BUY
# 5  135087M76         NaN         BOND      20231101   20210809  SELL
# 6  135087M76         NaN         BOND      20231101   20210809  SELL
# 7  135087M76         NaN         BOND      20231101   20210809  SELL
# 8  135087M76         NaN         BOND      20231101   20210809  SELL
# 9  135087L93         NaN         BOND      20260901   20210416  SELL
#
#    OrderQty  SettlDate  TransactTime   Price  Yield  DealerID  DealerTraderID  \
# 0   2400000   20211216      20231114     NaN    NaN       334         10792.0
# 1   2400000   20211216      20231114  98.720  1.281       335        117793.0
# 2   2400000   20211216      20231114  98.720  1.281       325        119290.0
# 3   2400000   20211216      20231114  98.711  1.283       327        113852.0
# 4   2400000   20211216      20231114  98.699  1.286       337        117795.0
# 5  15000000   20211216      20231114  99.162  0.952       325        119752.0
# 6  15000000   20211216      20231114  99.162  0.952       336        117794.0
# 7  15000000   20211216      20231114  99.160  0.953       323        117786.0
# 8  15000000   20211216      20231114  99.145  0.961       337        117795.0
# 9    600000   20211216      20231114  98.675  1.291       335        117793.0
#
#    CustomerTraderID  CustomerID  DealerCount
# 0              6549         129            5
# 1              6549         129            5
# 2              6549         129            5
# 3              6549         129            5
# 4              6549         129            5
# 5              7019         277            4
# 6              7019         277            4
# 7              7019         277            4
# 8              7019         277            4
# 9             11532         177            4

# %%
df['SecurityID'].isna().sum()
# Out:
# 13959

# %%
df.dropna(inplace=True)

# %%
df
# Out:
#           Symbol  SecurityID SecurityType  MaturityDate  IssueDate  Side  \
# 6204   135087D35   1657312.0          GOC      20481201   20140602   BUY
# 6205   135087D35   1657312.0          GOC      20481201   20140602   BUY
# 6206   135087H80   1657313.0          GOC      20200501   20180209  SELL
# 6207   135087D35   1657317.0          GOC      20481201   20140602   BUY
# 6208   135087D35   1657317.0          GOC      20481201   20140602   BUY
# ...          ...         ...          ...           ...        ...   ...
# 19995  135087A38    147039.0          GOC      20150801   20130426  SELL
# 19996  135087A38    147038.0          GOC      20150801   20130426   BUY
# 19997  013051CZ8    147033.0         PROV      20191201   20090928  SELL
# 19998  135087A38    147039.0          GOC      20150801   20130426  SELL
# 19999  013051CZ8    147033.0         PROV      20191201   20090928  SELL
#
#        OrderQty  SettlDate  TransactTime    Price  Yield  DealerID  \
# 6204    1000000   20180620      20231114  111.140  2.243       334
# 6205    1000000   20180620      20231114  111.220  2.240       335
# 6206    5000000   20180620      20231114   99.760  1.881       323
# 6207    1250000   20180620      20231114  111.198  2.241       321
# 6208    1250000   20180620      20231114  111.130  2.244       327
# ...         ...        ...           ...      ...    ...       ...
# 19995  12000000   20130624      20231114  100.651  1.186       334
# 19996  50000000   20130624      20231114  100.653  1.185       334
# 19997    700000   20130625      20231114  109.000  2.478       332
# 19998  12000000   20130624      20231114  100.645  1.189       330
# 19999    700000   20130625      20231114  109.099  2.462       330
#
#        DealerTraderID  CustomerTraderID  CustomerID  DealerCount
# 6204         113683.0             11570         454            4
# 6205         114347.0             11570         454            4
# 6206         118599.0              6753         204            1
# 6207           7177.0              6687         178            4
# 6208           7687.0              6687         178            4
# ...               ...               ...         ...          ...
# 19995         10792.0              7025         280            4
# 19996         10792.0              6753         204            1
# 19997         10567.0              7053         292            4
# 19998          9970.0              7025         280            4
# 19999         10189.0              7053         292            4
#
# [5685 rows x 16 columns]

# %%
df['Side'].value_counts()
# Out:
# SELL    2910
# BUY     2775
# Name: Side, dtype: int64

# %%
# Replacing categories with numbers
df['Side'].replace({'BUY': 1, 'SELL': 0}, inplace=True)
df
# Out:
#           Symbol  SecurityID SecurityType  MaturityDate  IssueDate  Side  \
# 6204   135087D35   1657312.0          GOC      20481201   20140602     1
# 6205   135087D35   1657312.0          GOC      20481201   20140602     1
# 6206   135087H80   1657313.0          GOC      20200501   20180209     0
# 6207   135087D35   1657317.0          GOC      20481201   20140602     1
# 6208   135087D35   1657317.0          GOC      20481201   20140602     1
# ...          ...         ...          ...           ...        ...   ...
# 19995  135087A38    147039.0          GOC      20150801   20130426     0
# 19996  135087A38    147038.0          GOC      20150801   20130426     1
# 19997  013051CZ8    147033.0         PROV      20191201   20090928     0
# 19998  135087A38    147039.0          GOC      20150801   20130426     0
# 19999  013051CZ8    147033.0         PROV      20191201   20090928     0
#
#        OrderQty  SettlDate  TransactTime    Price  Yield  DealerID  \
# 6204    1000000   20180620      20231114  111.140  2.243       334
# 6205    1000000   20180620      20231114  111.220  2.240       335
# 6206    5000000   20180620      20231114   99.760  1.881       323
# 6207    1250000   20180620      20231114  111.198  2.241       321
# 6208    1250000   20180620      20231114  111.130  2.244       327
# ...         ...        ...           ...      ...    ...       ...
# 19995  12000000   20130624      20231114  100.651  1.186       334
# 19996  50000000   20130624      20231114  100.653  1.185       334
# 19997    700000   20130625      20231114  109.000  2.478       332
# 19998  12000000   20130624      20231114  100.645  1.189       330
# 19999    700000   20130625      20231114  109.099  2.462       330
#
#        DealerTraderID  CustomerTraderID  CustomerID  DealerCount
# 6204         113683.0             11570         454            4
# 6205         114347.0             11570         454            4
# 6206         118599.0              6753         204            1
# 6207           7177.0              6687         178            4
# 6208           7687.0              6687         178            4
# ...               ...               ...         ...          ...
# 19995         10792.0              7025         280            4
# 19996         10792.0              6753         204            1
# 19997         10567.0              7053         292            4
# 19998          9970.0              7025         280            4
# 19999         10189.0              7053         292            4
#
# [5685 rows x 16 columns]

# %%
df['SecurityType'].value_counts()
# Replacing categories with numbers
df['SecurityType'].replace({'BOND': 1, 'GOC': 2,'PROV': 3,'CMB': 4}, inplace=True)
df
# Out:
#           Symbol  SecurityID  SecurityType  MaturityDate  IssueDate  Side  \
# 6204   135087D35   1657312.0             2      20481201   20140602     1
# 6205   135087D35   1657312.0             2      20481201   20140602     1
# 6206   135087H80   1657313.0             2      20200501   20180209     0
# 6207   135087D35   1657317.0             2      20481201   20140602     1
# 6208   135087D35   1657317.0             2      20481201   20140602     1
# ...          ...         ...           ...           ...        ...   ...
# 19995  135087A38    147039.0             2      20150801   20130426     0
# 19996  135087A38    147038.0             2      20150801   20130426     1
# 19997  013051CZ8    147033.0             3      20191201   20090928     0
# 19998  135087A38    147039.0             2      20150801   20130426     0
# 19999  013051CZ8    147033.0             3      20191201   20090928     0
#
#        OrderQty  SettlDate  TransactTime    Price  Yield  DealerID  \
# 6204    1000000   20180620      20231114  111.140  2.243       334
# 6205    1000000   20180620      20231114  111.220  2.240       335
# 6206    5000000   20180620      20231114   99.760  1.881       323
# 6207    1250000   20180620      20231114  111.198  2.241       321
# 6208    1250000   20180620      20231114  111.130  2.244       327
# ...         ...        ...           ...      ...    ...       ...
# 19995  12000000   20130624      20231114  100.651  1.186       334
# 19996  50000000   20130624      20231114  100.653  1.185       334
# 19997    700000   20130625      20231114  109.000  2.478       332
# 19998  12000000   20130624      20231114  100.645  1.189       330
# 19999    700000   20130625      20231114  109.099  2.462       330
#
#        DealerTraderID  CustomerTraderID  CustomerID  DealerCount
# 6204         113683.0             11570         454            4
# 6205         114347.0             11570         454            4
# 6206         118599.0              6753         204            1
# 6207           7177.0              6687         178            4
# 6208           7687.0              6687         178            4
# ...               ...               ...         ...          ...
# 19995         10792.0              7025         280            4
# 19996         10792.0              6753         204            1
# 19997         10567.0              7053         292            4
# 19998          9970.0              7025         280            4
# 19999         10189.0              7053         292            4
#
# [5685 rows x 16 columns]

# %%
df['Symbol'].value_counts()
# Out:
# 135087ZS6    250
# 135087D35    233
# 135087A61    159
# 135087YQ1    152
# 135087D50    140
#             ...
# 13509PFD0      1
# 642869AB7      1
# 68323AER1      1
# 642866GE1      1
# 135087XS8      1
# Name: Symbol, Length: 304, dtype: int64

# %%
from sklearn.preprocessing import LabelEncoder

# Initializing label encoder
label_encoder = LabelEncoder()

# Applying label encoder
df['code_numeric'] = label_encoder.fit_transform(df['Symbol'])
df
# Out:
#           Symbol  SecurityID  SecurityType  MaturityDate  IssueDate  Side  \
# 6204   135087D35   1657312.0             2      20481201   20140602     1
# 6205   135087D35   1657312.0             2      20481201   20140602     1
# 6206   135087H80   1657313.0             2      20200501   20180209     0
# 6207   135087D35   1657317.0             2      20481201   20140602     1
# 6208   135087D35   1657317.0             2      20481201   20140602     1
# ...          ...         ...           ...           ...        ...   ...
# 19995  135087A38    147039.0             2      20150801   20130426     0
# 19996  135087A38    147038.0             2      20150801   20130426     1
# 19997  013051CZ8    147033.0             3      20191201   20090928     0
# 19998  135087A38    147039.0             2      20150801   20130426     0
# 19999  013051CZ8    147033.0             3      20191201   20090928     0
#
#        OrderQty  SettlDate  TransactTime    Price  Yield  DealerID  \
# 6204    1000000   20180620      20231114  111.140  2.243       334
# 6205    1000000   20180620      20231114  111.220  2.240       335
# 6206    5000000   20180620      20231114   99.760  1.881       323
# 6207    1250000   20180620      20231114  111.198  2.241       321
# 6208    1250000   20180620      20231114  111.130  2.244       327
# ...         ...        ...           ...      ...    ...       ...
# 19995  12000000   20130624      20231114  100.651  1.186       334
# 19996  50000000   20130624      20231114  100.653  1.185       334
# 19997    700000   20130625      20231114  109.000  2.478       332
# 19998  12000000   20130624      20231114  100.645  1.189       330
# 19999    700000   20130625      20231114  109.099  2.462       330
#
#        DealerTraderID  CustomerTraderID  CustomerID  DealerCount  code_numeric
# 6204         113683.0             11570         454            4            58
# 6205         114347.0             11570         454            4            58
# 6206         118599.0              6753         204            1            77
# 6207           7177.0              6687         178            4            58
# 6208           7687.0              6687         178            4            58
# ...               ...               ...         ...          ...           ...
# 19995         10792.0              7025         280            4            41
# 19996         10792.0              6753         204            1            41
# 19997         10567.0              7053         292            4             0
# 19998          9970.0              7025         280            4            41
# 19999         10189.0              7053         292            4             0
#
# [5685 rows x 17 columns]

# %%
# df_encoded = pd.get_dummies(df, columns=['Symbol'])
# df_encoded
df.drop('Symbol',axis=1,inplace = True)

# %% [markdown]
# ## Step 3.1: Select and Import a ML Algorithm. (5%)
# <span style="color:red">
#     TODO: Based on your rationale provided in Step 1, import one of the following algorithms:
#     <ul>
#     <li>for Supervised Classification ML use <b>'from sklearn.ensemble import RandomForestClassifier'</b></li>
#     <li>for Supervised Regression ML use <b>'from sklearn.ensemble import RandomForestRegressor'</b></li>
#     <li>for Unsupervised ML use <b>'from sklearn.cluster import KMeans'</b></li>
#     </ul>
# </span>

# %%
from sklearn.model_selection import train_test_split

# %%
Y = df.iloc[:, df.columns.get_loc('Price')]
X = df.loc[:, df.columns != 'Price']

# %%
X_train, X_test, Y_train, Y_test = train_test_split(X,Y, test_size=0.2, random_state=0)

# %%
X_train
# Out:
#        SecurityID  SecurityType  MaturityDate  IssueDate  Side  OrderQty  \
# 10127    597209.0             4      20240615   20140227     1      6000
# 19160   2314777.0             2      20531201   20210803     1    100000
# 15917    273653.0             2      20180901   20130513     0   4000000
# 14979    816003.0             2      20451201   20110613     0   4041000
# 19814   2314913.0             2      20330601   20011015     0     49000
# ...           ...           ...           ...        ...   ...       ...
# 19195   2314787.0             3      20451201   20130430     0     50000
# 15354   1076920.0             2      20370601   20070115     1   1000000
# 9998     597156.0             2      20170201   20131015     0  10000000
# 14653   1134363.0             2      20181101   20160812     1   5000000
# 14794    815882.0             2      20220601   20110802     1   4437000
#
#        SettlDate  TransactTime  Yield  DealerID  DealerTraderID  \
# 10127   20150129      20231114  1.681       330         12940.0
# 19160   20220324      20231114  2.497       337          5168.0
# 15917   20131127      20231114  1.767       325          7632.0
# 14979   20151105      20231114  2.331       334        113683.0
# 19814   20220324      20231114  2.511       323        118599.0
# ...          ...           ...    ...       ...             ...
# 19195   20220322      20231114  3.449       325        119335.0
# 15354   20160927      20231114  1.704       337         11234.0
# 9998    20150130      20231114  0.444       323        118599.0
# 14653   20161130      20231114  0.657       337          5168.0
# 14794   20151105      20231114  1.187       327        114381.0
#
#        CustomerTraderID  CustomerID  DealerCount  code_numeric
# 10127             13346          70            3           153
# 19160             12951         124            5            94
# 15917             13370         340            3            49
# 14979              6419          82            4           124
# 19814            113770          19            5           106
# ...                 ...         ...          ...           ...
# 19195             12951         124            5           283
# 15354              7073         300            4           108
# 9998               7014         277            4            52
# 14653              6753         204            4            67
# 14794              6993         269            2           125
#
# [4548 rows x 15 columns]

# %%
Y_train
# Out:
# 10127    110.537
# 19160     83.705
# 15917     97.650
# 14979    125.160
# 19814    131.422
#           ...
# 19195    100.819
# 15354    157.231
# 9998     102.105
# 14653     99.700
# 14794    109.854
# Name: Price, Length: 4548, dtype: float64

# %%
from sklearn.ensemble import RandomForestRegressor

random_forest_regressor = RandomForestRegressor()
random_forest_regressor.fit(X_train, Y_train)
# Out:
# RandomForestRegressor()

# %% [markdown]
# ## Step 3.2: Train the ML Model. (10%)
# <span style="color:red">
#     TODO:
#     <ul>
#     <li>from the preprocessed dataset, extract 𝑋 - a dataset of all the features but 'Price'</li>
#     <li>from the preprocessed dataset, extract 𝑌  - vector that contains all the values of 'Price'</li>
#     <li>slice the dataset: 80% for training and 20% for testing</li>
#     <li>create an instance of the selected ML algorithm and train</li>
#     </ul>
# </span>

# %%
from sklearn import metrics

# %%
Y_pred = random_forest_regressor.predict(X_test)
Y_pred
# Out:
# array([100.3581 , 131.66643, 111.02628, ..., 103.85494, 136.05434,
#        114.42328])

# %% [markdown]
# ## Step 3.3: Test the ML Model. (5%)
# <span style="color:red">
#     TODO:
#     <ul>
#     <li>use the testing part of the dataset to predic the Bond Prices</li>
#     <li>compute and show the prediction score</li>
#     </ul>
# </span>

# %%
from sklearn import metrics
r2_score = metrics.r2_score(Y_test,Y_pred)
print(r2_score)
# Out:
# 0.9964844119957098

# %%
sns.regplot(x=Y_test,y=Y_pred,ci=None,color ='red')
# Out:
# <Axes: xlabel='Price'>

# %%
import matplotlib.pyplot as plt
import numpy as np
from sklearn.ensemble import RandomForestRegressor

# Assuming you have a dataset with X_train and y_train
# Create and fit the model

# Get feature importances
importances = random_forest_regressor.feature_importances_
indices = np.argsort(importances)[::-1]

# summarize feature importance
for i,v in enumerate(importances):
    print('Feature: ' + X.columns[i] + ': %.5f' % (v))

# Plot
plt.figure()
plt.title("Feature Importances")
plt.bar(range(X_train.shape[1]), importances[indices], align="center")
plt.xticks(range(X_train.shape[1]), indices)
plt.xlim([-1, X_train.shape[1]])
plt.show()
# Out:
# Feature: SecurityID: 0.02484
# Feature: SecurityType: 0.00037
# Feature: MaturityDate: 0.28298
# Feature: IssueDate: 0.56891
# Feature: Side: 0.00018
# Feature: OrderQty: 0.00131
# Feature: SettlDate: 0.00364
# Feature: TransactTime: 0.00000
# Feature: Yield: 0.11010
# Feature: DealerID: 0.00007
# Feature: DealerTraderID: 0.00015
# Feature: CustomerTraderID: 0.00092
# Feature: CustomerID: 0.00075
# Feature: DealerCount: 0.00043
# Feature: code_numeric: 0.00535

# %%
r2_score_new = metrics.r2_score(Y_test,Y_pred)
print("The r2_score " + str(r2_score))
print("The r2_score  " + str(r2_score_new))
# Out:
# The r2_score 0.9964844119957098
# The r2_score  0.9964844119957098

# %%
df.corr()
# Out:
#                   SecurityID  SecurityType  MaturityDate  IssueDate      Side  \
# SecurityID          1.000000      0.027270      0.224900   0.349992  0.022393
# SecurityType        0.027270      1.000000     -0.053040  -0.113370  0.028906
# MaturityDate        0.224900     -0.053040      1.000000  -0.105174  0.032260
# IssueDate           0.349992     -0.113370     -0.105174   1.000000  0.099733
# Side                0.022393      0.028906      0.032260   0.099733  1.000000
# OrderQty           -0.041880     -0.138359     -0.225839   0.137944  0.018565
# SettlDate           0.980133      0.008031      0.232489   0.335659  0.004082
# TransactTime             NaN           NaN           NaN        NaN       NaN
# Price              -0.196165     -0.046897      0.436881  -0.765779 -0.049664
# Yield               0.314373      0.237970      0.663056  -0.149472 -0.004091
# DealerID           -0.085613     -0.053874     -0.029173  -0.015393 -0.038905
# DealerTraderID      0.167034     -0.095092      0.059938   0.070026 -0.006944
# CustomerTraderID    0.441316      0.070024      0.113022   0.099718 -0.028800
# CustomerID          0.098413     -0.224547     -0.144637   0.249419  0.027472
# DealerCount         0.164538     -0.004957      0.162695  -0.043486 -0.044090
# code_numeric        0.057939      0.566830      0.189871  -0.259544  0.014616
#
#                   OrderQty  SettlDate  TransactTime     Price     Yield  \
# SecurityID       -0.041880   0.980133           NaN -0.196165  0.314373
# SecurityType     -0.138359   0.008031           NaN -0.046897  0.237970
# MaturityDate     -0.225839   0.232489           NaN  0.436881  0.663056
# IssueDate         0.137944   0.335659           NaN -0.765779 -0.149472
# Side              0.018565   0.004082           NaN -0.049664 -0.004091
# OrderQty          1.000000  -0.034452           NaN -0.162750 -0.213653
# SettlDate        -0.034452   1.000000           NaN -0.163556  0.301130
# TransactTime           NaN        NaN           NaN       NaN       NaN
# Price            -0.162750  -0.163556           NaN  1.000000  0.234476
# Yield            -0.213653   0.301130           NaN  0.234476  1.000000
# DealerID          0.021452  -0.083392           NaN -0.023935  0.005649
# DealerTraderID   -0.011140   0.185752           NaN -0.009580  0.006079
# CustomerTraderID -0.082055   0.426905           NaN -0.079963  0.180636
# CustomerID        0.088343   0.076291           NaN -0.196900 -0.173805
# DealerCount      -0.121852   0.196769           NaN  0.062737  0.147757
# code_numeric     -0.170499   0.051791           NaN  0.212544  0.412281
#
#                   DealerID  DealerTraderID  CustomerTraderID  CustomerID  \
# SecurityID       -0.085613        0.167034          0.441316    0.098413
# SecurityType     -0.053874       -0.095092          0.070024   -0.224547
# MaturityDate     -0.029173        0.059938          0.113022   -0.144637
# IssueDate        -0.015393        0.070026          0.099718    0.249419
# Side             -0.038905       -0.006944         -0.028800    0.027472
# OrderQty          0.021452       -0.011140         -0.082055    0.088343
# SettlDate        -0.083392        0.185752          0.426905    0.076291
# TransactTime           NaN             NaN               NaN         NaN
# Price            -0.023935       -0.009580         -0.079963   -0.196900
# Yield             0.005649        0.006079          0.180636   -0.173805
# DealerID          1.000000        0.028682         -0.030950    0.037318
# DealerTraderID    0.028682        1.000000          0.042293    0.043400
# CustomerTraderID -0.030950        0.042293          1.000000    0.093440
# CustomerID        0.037318        0.043400          0.093440    1.000000
# DealerCount      -0.007127        0.076649          0.134251   -0.066284
# code_numeric     -0.036998       -0.063468          0.100237   -0.251771
#
#                   DealerCount  code_numeric
# SecurityID           0.164538      0.057939
# SecurityType        -0.004957      0.566830
# MaturityDate         0.162695      0.189871
# IssueDate           -0.043486     -0.259544
# Side                -0.044090      0.014616
# OrderQty            -0.121852     -0.170499
# SettlDate            0.196769      0.051791
# TransactTime              NaN           NaN
# Price                0.062737      0.212544
# Yield                0.147757      0.412281
# DealerID            -0.007127     -0.036998
# DealerTraderID       0.076649     -0.063468
# CustomerTraderID     0.134251      0.100237
# CustomerID          -0.066284     -0.251771
# DealerCount          1.000000      0.035320
# code_numeric         0.035320      1.000000
